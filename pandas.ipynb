# %%
import numpy as np 
import pandas as pd

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1=pd.DataFrame([[1,3,5,7],[2,4,6,8],[3,5,7,9],[4,6,8,10],[4,2,1,8]], columns=['A','B','C','D'])

# %%
df1
# Out:
#    A  B  C   D
# 0  1  3  5   7
# 1  2  4  6   8
# 2  3  5  7   9
# 3  4  6  8  10
# 4  4  2  1   8

# %%
print(df1)
# Out:
#    A  B  C   D
# 0  1  3  5   7
# 1  2  4  6   8
# 2  3  5  7   9
# 3  4  6  8  10
# 4  4  2  1   8

# %%
df1.head()
# Out:
#    A  B  C   D
# 0  1  3  5   7
# 1  2  4  6   8
# 2  3  5  7   9
# 3  4  6  8  10
# 4  4  2  1   8

# %%
df1.head(3)
# Out:
#    A  B  C  D
# 0  1  3  5  7
# 1  2  4  6  8
# 2  3  5  7  9

# %%
df1.tail()
# Out:
#    A  B  C   D
# 0  1  3  5   7
# 1  2  4  6   8
# 2  3  5  7   9
# 3  4  6  8  10
# 4  4  2  1   8

# %%
df1.tail(2)
# Out:
#    A  B  C   D
# 3  4  6  8  10
# 4  4  2  1   8

# %%
df1.shape
# Out:
# (5, 4)

# %%
df1.iloc[0:2,1:3]
# Out:
#    B  C
# 0  3  5
# 1  4  6

# %%
df2=pd.read_csv('data.csv')

# %% [markdown]
# df2

# %%
df2
# Out:
#              V1         V2
# 0      2.072345  -3.241693
# 1     17.936710  15.784810
# 2      1.083576   7.319176
# 3     11.120670  14.406780
# 4     23.711550   2.557729
# 5     24.169930  32.024780
# 6     21.665780   4.892855
# 7      4.693684  12.342170
# 8     19.211910  -1.121366
# 9      4.230391  -4.441536
# 10     9.127130  23.605720
# 11     0.407503  15.297050
# 12     7.314846   3.309312
# 13    -3.438403 -12.025270
# 14    17.639350  -3.212345
# 15     4.415292  22.815550
# 16    11.941220   8.122487
# 17     0.725853   1.806819
# 18     8.185273  28.132600
# 19    -5.773587   1.024800
# 20    18.769430  24.169460
# 21     7.752016  -3.334991
# 22    10.611320  28.443780
# 23     2.021650  -4.687122
# 24     5.145525  11.186000
# 25     6.243310  19.477160
# 26   -11.706710   8.073185
# 27     7.255978  14.637040
# 28     3.392373   1.220712
# 29    24.299900  40.428870
# ...         ...        ...
# 2970  84.633760 -10.654310
# 2971  59.708580  -7.022610
# ...

# %%
df2.shape
# Out:
# (3000, 2)

# %%
df2.head()
# Out:
#           V1         V2
# 0   2.072345  -3.241693
# 1  17.936710  15.784810
# 2   1.083576   7.319176
# 3  11.120670  14.406780
# 4  23.711550   2.557729

# %%
df2['V1'].dtype
# Out:
# dtype('float64')

# %%
print(df2['V1'].dtype)
# Out:
# float64

# %%
print(df2["V2"].head())
# Out:
# 0    -3.241693
# 1    15.784810
# 2     7.319176
# 3    14.406780
# 4     2.557729
# Name: V2, dtype: float64

# %%
print(df2["V2"])
# Out:
# 0       -3.241693
# 1       15.784810
# 2        7.319176
# 3       14.406780
# 4        2.557729
# 5       32.024780
# 6        4.892855
# 7       12.342170
# 8       -1.121366
# 9       -4.441536
# 10      23.605720
# 11      15.297050
# 12       3.309312
# 13     -12.025270
# 14      -3.212345
# 15      22.815550
# 16       8.122487
# 17       1.806819
# 18      28.132600
# 19       1.024800
# 20      24.169460
# 21      -3.334991
# 22      28.443780
# 23      -4.687122
# 24      11.186000
# 25      19.477160
# 26       8.073185
# 27      14.637040
# 28       1.220712
# 29      40.428870
#           ...
# 2970   -10.654310
# 2971    -7.022610
# 2972     0.278247
# 2973   -20.880200
# 2974    -3.268589
# 2975    -9.672550
# 2976     6.197267
# 2977   -17.894410
# 2978   -20.291110
# 2979   -12.982000
# 2980   -22.742850
# 2981     2.738940
# 2982    -7.237918
# 2983   -12.987290
# 2984   -17.637640
# 2985   -15.765600
# 2986   -18.703770
# 2987   -15.101860
# 2988   -22.094270
# ...

# %%
df1.to_csv('export.csv', index=False)

# %% [markdown]
# ## MERGING DATAFRAMES

# %%
a=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C'])

# %%
a
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
b=pd.DataFrame([[11,2,33],[44,5,66],[77,88,99]],columns=['X','Y','Z'])

# %%
b
# Out:
#     X   Y   Z
# 0  11   2  33
# 1  44   5  66
# 2  77  88  99

# %%
mrg=pd.merge(a,b,right_on='Y',left_on='B')

# %%
mrg
# Out:
#    A  B  C   X  Y   Z
# 0  1  2  3  11  2  33
# 1  4  5  6  44  5  66

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],'value': [5, 6, 7, 8]})

# %%
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7

# %%
df1.merge(df2, left_on='lkey', right_on='rkey',suffixes=('_left', '_right'))
# Out:
#   lkey  value_left rkey  value_right
# 0  foo           1  foo            5
# 1  foo           1  foo            8
# 2  foo           5  foo            5
# 3  foo           5  foo            8
# 4  bar           2  bar            6
# 5  baz           3  baz            7
